# %%
def find_len(list1): 
    length = len(list1) 
    list1.sort() 
    print("Largest element is:", list1[length-1]) 
    print("Second Largest element is:", list1[length-2])  
list1=[12, 45, 2, 41, 31, 10, 8, 6, 4] 
Largest = find_len(list1)
# Out:
# Largest element is: 45
# Second Largest element is: 41

# %%
def checkYear(year):
    if (year % 4) == 0:
        if (year % 100) == 0:
            if (year % 400) == 0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

year =int(input("Enter year between 2000 to 2020 : ")) 
if year in range(2000,2020):
    if(checkYear(year)):
        mm = (input("Enter month: "))  
        print( mm  + " "+  str(year) +" " +  "Leap Year")
    else:
        print("Not a Leap Year")
else:
    print ("not a valid input")
# Out:
# Enter year between 2000 to 2020 : 2004
# Enter month: june
# june 2004 Leap Year

# %%
my_list = ['sharanu', 'shreyas', 'shashi', 'sriram','sheetal', 'bhumika','sinchana', 'tejaswini',  'sushmita','shamanth','siddhanth','somil']
        
n = 4

  
x = [my_list[i:i + n] for i in range(0, len(my_list),n)]  
print(x)
# Out:
# [['sharanu', 'shreyas', 'shashi', 'sriram'], ['sheetal', 'bhumika', 'sinchana', 'tejaswini'], ['sushmita', 'shamanth', 'siddhanth', 'somil']]

# %%
L = [(), (), ('',), ('a', 'b'), ('a', 'b', 'c'), ('d')]
L = [t for t in L if t]
print(L)
# Out:
# [('',), ('a', 'b'), ('a', 'b', 'c'), 'd']

# %%
int_list = [] 
max_length = int(input("enter the length of the list: "))

while len(int_list) < max_length:
   
    while True:
        try:
            item = int(input("append an interger into the list: "))
            break
        except ValueError:
            print("error: invalid input")
    
    if item in range(1, 100):
        int_list.append(item)
        print(int_list)


print("list of values entered between 1 to 100:")
print(int_list)
# Out:
# enter the length of the list: 4
# append an interger into the list: 12
# [12]
# append an interger into the list: 14
# [12, 14]
# append an interger into the list: 14
# [12, 14, 14]
# append an interger into the list: 15
# [12, 14, 14, 15]
# list of values entered between 1 to 100:
# [12, 14, 14, 15]

# %%
fname = []
fname = input("Enter the first names: ").split()
a_count = 0
for name in fname:
    if 'a' in name:
        a_count = a_count + name.count('a')
print("'a' occurs", a_count,"times")
# Out:
# Enter the first names: aaasdf
# 'a' occurs 3 times

# %%
  
def bubbleSort(arr): 
    n = len(arr) 
    for i in range(n-1): 
        for j in range(0, n-i-1): 
  
            if arr[j] > arr[j+1] : 
                arr[j], arr[j+1] = arr[j+1], arr[j] 
  
arr = [64, 34, 25, 12, 22, 11, 90] 
  
bubbleSort(arr)
print ("Sorted array is:") 
for i in range(len(arr)): 
    print ("%d" %arr[i]),
# Out:
# Sorted array is:
# 11
# 12
# 22
# 25
# 34
# 64
# 90

# %%
def getDailyTemps():
    days = ["Sunday", "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday"]
    temperature = []
    for i in range (len(days)):
        temp_input = input ("Enter the temperature for "  + days[i]+str(":"))
        temperature.append(temp_input)



    averageTemp = {}
    i = 0
    for day in days:
        averageTemp[day] = temperature[i]
        i = i + 1
    return averageTemp

finalDict = getDailyTemps()
print(finalDict)
# Out:
# Enter the temperature for Sunday:31\
# Enter the temperature for Monday:33
# Enter the temperature for Tuesday:43
# Enter the temperature for Wednesday:5
# Enter the temperature for Thursday:36
# Enter the temperature for Friday:36
# Enter the temperature for Saturday:7
# {'Sunday': '31\\', 'Monday': '33', 'Tuesday': '43', 'Wednesday': '5', 'Thursday': '36', 'Friday': '36', 'Saturday': '7'}

# %%
n = int(input("No of words = "))
words = []
for _ in range(n):
    words.append(input("Enter the word: "))

sentence = []



sentence = ' '.join([str(elem) for elem in words]) 
print(sentence)
# Out:
# No of words = 4
# Enter the word: sharanu
# Enter the word: is
# Enter the word: a
# Enter the word: good boy
# sharanu is  a  good boy

# %%
str = "the clown ran after the car and the car ran into the tent and the tent fell dowdn on the clown and the car"

words = str.split()

wordFreq = {}

for word in words:
    if word not in wordFreq:
        wordFreq[word] = 0
    wordFreq[word] = wordFreq[word] + 1

mostCommon = max(wordFreq, key = lambda x: wordFreq[x])
print(mostCommon,"has occured", wordFreq[mostCommon], "times")
# Out:
# the has occured 7 times

# %%
n = int(input("Enter the value of 'n': "))
a = 0
b = 1
sum = 0
count = 1
print("Fibonacci Series: ", end = " ")
while(count <= n):
  print(sum, end = " ")
  count += 1
  a = b
  b = sum
  sum = a + b
# Out:
# Enter the value of 'n': 4
# Fibonacci Series:  0 1 1 2

# %%
list= [(6, 'yonder'), (6, 'window'), (6, 'breaks'), (5, 'light')]
print( sorted(list, key=lambda x: x[0], reverse=True))
# Out:
# [(6, 'yonder'), (6, 'window'), (6, 'breaks'), (5, 'light')]

# %%
import random
n = int(input("Enter the value of n: "))
lst = []
for _ in range(n):
    lst.append(random.randint(0, n))
lst.sort()
print(lst)
# Out:
# Enter the value of n: 15
# [0, 0, 0, 0, 2, 3, 4, 6, 6, 6, 7, 11, 11, 13, 13]
